# %%
import os
import numpy as np
import pandas as pd

df = pd.read_excel('/content/20220101_20220113_현대차_네이버_기사.xlsx')
df.corr(method='pearson')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
title_list = df['제목'].values.tolist()
title_slice = []
for i in range(0, len(title_list)):
    title_slice += title_list[i].split(' ')
len(title_slice)
# Out:
# 82515

# %%
titleCount = {} 
 
for title in title_slice:
    titleCount[title] = titleCount.get(title, 0) + 1
    titleKeys = sorted(titleCount.keys())

# %%
for word in titleKeys:
    if titleCount[word] > 20:
        print(word + ':' + str(titleCount[word]))
# Out:
# "공급:23
# "공급물량:23
# "대기업:59
# "반도체:31
# "중대재해법:23
# "현대차:39
# '2022:142
# 'i20:190
# 'i20N',:46
# '대기업:25
# '레드:264
# '사전협상제도':95
# '세실리아:214
# '수소:95
# '스타리아',:40
# '아우토빌트':65
# '아이오닉:437
# '아이오닉5',:143
# '압승':22
# '최고:97
# '최고의:457
# '최우수상':26
# '카즈닷컴':83
# '팔자'에:35
# '평택시:39
# '폭스바겐:23
# '폴로:215
# '한화ARIRANG:27
# '현대:151
# '현대차:26
# 10%:27
# 1000만대:41
# 17%:25
# 17%↓:39
# 1~2월:47
# 1대는:22
# 1분기:47
# 1위:386
# 2.3만여대:27
# 2022:251
# 2022년:160
# 2030년:46
# 2030년까지:809
# 23명:34
# 2730선:32
# 2740선:26
# 2750선:25
# 2개:40
# 2만3784대:26
# 2만3794대:53
# 2만3천여대:29
# 30만:23
# 31만3926대:39
# 3개·본상:26
# 3대:220
# 3연승:144
# 3월:220
# 40대:191
# 5':36
# 5',:402
# 5,:410
# 50만대:33
# 520d:51
# 5’:26
# 5’,:87
# 5개:680
# 5사,:24
# 60.8만대:24
# 65개:115
# 850대:1033
# 8개사:109
# BMW:42
# ETF:131
# ETF':61
# ETF’:27
# EV':48
# GTI:45
# GTI':138
# GTI'와:79
# GTI’:23
# GTI’와:33
# GV60:25
# HMM:62
# HMM,:75
# MOU:75
# N:23
# N',:191
# N,:24
# N’,:44
# PTU:32
# QM6:40
# SK:21
# VS:24
# VW:44
# [2022:35
# [기업]:28
# [마감시황]:24
# [마감시황]코스피,:21
# [시황]:32
# [종합]:29
# [특징주]:40
# i20:36
# i20N:22
# i20N,:124
# iSelect우주항공&UAM:63
# vs:26
# ·:38
# ‘2022:58
# ‘3연승’:22
# ‘i20:44
# ‘글로벌:23
# ‘레드:71
# ‘레드닷:21
# ‘세실리아:49
# ‘아이오닉:122
# ‘아이오닉5’,:49
# ‘최고의:214
# ‘카즈닷컴’:33
# ‘폴로:67
# ‘현대:111
# 外:25
# 獨:292
# 獨레드닷:25
# 獨서:40
# 美:786
# 美서:140
# 美카즈닷컴:32
# 英:69
# 車:25
# 車전문지:92
# 가능한:43
# 가장:31
# 가족용:1184
# 감소:47
# 강보합:25
# 강세:29
# 강화:26
# 개발:217
# 개선:22
# 개선…사전컨설팅:25
# 개최:40
# 개통식:25
# 것":50
# 것”:26
# 결과는?:23
# 경쟁력:88
# 고객:97
# 공급:866
# 공급망:30
# 공급한다:92
# 공장:23
# 공장서:23
# 관련:21
# 관련주:26
# 구축:35
# 국내:196
# 국산:21
# 국토부,:26
# 규모:39
# 규모의:22
# 근로자:46
# 글로벌:250
# 급등:26
# 기관:67
# 기대:36
# 기아:37
# 기아,:33
# 기업:42
# 긴장:21
# 김경배:121
# 꺾었다:23
# 나서:25
# 나선다:26
# 노동자:310
# 누적생산:32
# 늘려:35
# 단체:30
# 달성:54
# 닷:827
# 대규모:58
# 대기:22
# 대기업:80
# 대비:22
# 대상:47
# 대상지:42
# 대응":22
# 대표:38
# 대표이사:86
# 더:28
# 도약":63
# 도입:22
# 독일:423
# 독일서:118
# 돌입:21
# 돌파:76
# 동반:30
# 등:825
# 디자인:252
# 디자인분야:32
# 디자인상:186
# 레드:492
# 레드닷:115
# 레드닷어워드서:33
# 로봇:46
# 르노삼성:28
# 르노삼성·BMW·현대·기아:38
# 리더:82
# 리콜:281
# 마감:125
# 만에:35
# 맞손:21
# 매도에:32
# 매수세에:23
# 매수에:26
# 매체:71
# 매출:25
# 모두:40
# 모빌리티:244
# 모집:46
# 문화예술:26
# 미:36
# 미국:91
# 미국서:135
# 미국서도:33
# 미래:47
# 민간:21
# 민간부지:137
# 반도체:72
# 받아:37
# 버스:36
# 번째:23
# 보급:47
# 보합권:22
# 본격화:22
# 본고장:25
# 부문:130
# 부산시,:38
# 분야:283
# 비교:245
# 비교평가:109
# 비교평가서:183
# 비중:25
# 비쿠냐:183
# 비쿠냐':214
# 비쿠냐’:49
# 뽑혀:81
# 사내이사:442
# 사망:128
# 사망…중대재해법:26
# 사망…중대재해처벌법:21
# 사망사고:21
# 사업:30
# 사장:60
# 산업:26
# 삼성전자:35
# 상반기:45
# 상복:47
# 상승:133
# 상용차:76
# 상장:52
# 생산:36
# 생태계:55
# 서비스:27
# 서울시,:155
# 석권:64
# 선발:41
# 선사:27
# 선사로:26
# 선임:28
# 선정:1397
# 성장:39
# 세계:134
# 세실리아:205
# 소폭:21
# 속:48
# 수:28
# 수급난:32
# 수상:765
# 수소:333
# 수소경제:23
# 수소기업:70
# 수소버스:22
# 수소버스로:24
# 수소산업:34
# 수소상용차:50
# 수소차:82
# 수소트럭:40
# 수소트럭,:26
# 수소트럭/버스:75
# 수소트럭·버스:633
# 수소트럭ㆍ버스:34
# 순매수:21
# 숨져…중대재해법:29
# 스칼러십,:61
# 스칼러십’:24
# 스타리아,:67
# 스타리아로:36
# 시내버스:30
# 시동:37
# 시장:200
# 신규:25
# 신임:41
# 신입·경력:63
# 실적:22
# 쌍용차:32
# 쏘카와:38
# 아람코와:21
# 아세안:71
# 아우디·폴스타:83
# 아우토빌트:74
# 아이오닉:421
# 아이오닉5:54
# 아이오닉5,:507
# 압승:22
# 어워드:276
# 어워드':344
# 어워드'서:65
# 어워드’:117
# 어워드서:124
# 업계:34
# 업무협약:25
# 엔진·연료:23
# 여부:50
# 역대:79
# 연계:35
# 연구개발본부:46
# 연료:24
# 연료호스:39
# 열리는:23
# 영예:55
# 예정:25
# 오늘:23
# 올라:21
# 올해:94
# 완성차:89
# 완화에:29
# 외국인:51
# 외인:24
# 외인·기관:31
# 우려:52
# 우주항공:42
# 우주항공·UAM:33
# 우크라:21
# 운영체제:38
# 위반:164
# 위한:42
# 위해:36
# 유럽:36
# 유치:81
# 육성:100
# 이번엔:30
# 이어:54
# 이종진:24
# 인재:47
# 인정:23
# 인정한:27
# 인천:44
# 인천시,:68
# 일곱:23
# 일자리:33
# 잇단:23
# 있는:40
# 자동차:139
# 자동차전문지:23
# 작가:35
# 작가로:36
# 작가에:288
# 작업:40
# 작품:35
# 장:22
# 장재훈:57
# 장학생:52
# 재단,:77
# 재선임:182
# 재선임…:25
# 적용:36
# 전기:21
# 전기차:596
# 전기차":74
# 전기차':351
# 전기차'로:115
# 전기차’:187
# 전기차’로:34
# 전기차로:206
# 전년比:38
# 전문지:102
# 전세계:42
# 전시:304
# 전용:52
# 전주공장:80
# 전주공장서:267
# 전환:39
# 정몽구:144
# 정부-지자체-민간:30
# 정의선:297
# 정의선,:64
# 제고:21
# 제작결함:28
# 제쳐:151
# 제쳤다:30
# 제치고:80
# 제친:32
# 제품:140
# 제품디자인:238
# 조사:225
# 조성:82
# 조성':68
# 주가:50
# 주요:24
# 주주:28
# 주총:35
# 주총,:40
# 주총]:34
# 주총서:43
# 주행:28
# 중:138
# 중":46
# 중고차:256
# 중고차시장:25
# 중고차업계:31
# 중고차업계,:32
# 중대재해법:57
# 증서:27
# 지난달:24
# 지원:23
# 진출:129
# 진출,:43
# 진출에:26
# 진출은:22
# 차세대:89
# 차종:118
# 차종,:26
# 채용:70
# 첫:58
# 청라에:29
# 체결:81
# 초반:22
# 총:39
# 최고:84
# 최고의:362
# 최다:21
# 최대:105
# 최대로:33
# 최소화":23
# 최우수상:554
# 최적배분해:31
# 최초:63
# 최태원:23
# 출발:23
# 출시:155
# 출신:32
# 친환경:77
# 친환경차:61
# 카:63
# 카즈닷컴:346
# 카즈닷컴서:61
# 커넥티드:42
# 커미션:45
# 커미션':132
# 커미션’:105
# 코스피:128
# 코스피,:313
# 쾌거:27
# 터진:47
# 테마:21
# 테슬라:32
# 테이트모던서:23
# 톱:38
# 톱클래스:33
# 투자:61
# 투자하는:40
# 트럭:22
# 트럭·버스:106
# 특구:222
# 특구':29
# 파괴":21
# 파트너십,:36
# 판매:231
# 판매량:60
# 패밀리:36
# 패밀리카':32
# 평가:157
# 평가서:338
# 평택:22
# 평택시:97
# 평택시에:921
# 평택에:88
# 포함:43
# 폭스바겐:373
# 폴로:126
# 프로젝트:25
# 하락:99
# 하이브리드:24
# 한화운용,:29
# 한화자산운용,:159
# 함께:24
# 핵심부품:35
# 혁신:22
# 현대:142
# 현대위아,:40
# 현대자동차:48
# 현대자동차,:122
# 현대차:2873
# 현대차,:1979
# 현대차·기아:43
# 현대차·기아,:57
# 현대차·테이트:36
# 현대차…:24
# 현대차그룹:67
# 현대차그룹,:845
# 현대커미션:28
# 협력:36
# 협상:30
# 호스:28
# 호평:79
# 화재:44
# 확대:50
# 확대"…정의선:27
# 활용:41
# 회복:32
# 회장:227
# 회장,:32
# 휩쓸어:27
# 휴림로봇,:28
