# %%
# !pip install finance-datareader
# Out:
# ...
#      |████████████████████████████████| 48 kB 1.7 MB/s
# ...

# %%
import pandas as pd
import csv

df_search = pd.read_csv('/content/multiTimeline.csv', encoding='cp949')
df_search
# Out:
#                 날짜  현대차  크래프톤  대한항공  카카오페이
# 0    2022-03-30T17   47    40    58     91
# 1    2022-03-30T18   53    28    46     64
# 2    2022-03-30T19   46    28    48     73
# 3    2022-03-30T20   27    26    38     54
# 4    2022-03-30T21   25    17    38     65
# ..             ...  ...   ...   ...    ...
# 163  2022-04-06T12   61    35    81     55
# 164  2022-04-06T13   47    51    76     60
# 165  2022-04-06T14   63     7    70     53
# 166  2022-04-06T15   58    64    56     66
# 167  2022-04-06T16   65     0    75     77
#
# [168 rows x 5 columns]

# %%
import FinanceDataReader as fdr
df_krx = fdr.StockListing('KRX')

# %%
df = fdr.DataReader('259960','2022-03-28', '2022-04-06')
df
# Out:
#               Open    High     Low   Close  Volume    Change
# Date
# 2022-03-28  278500  279000  270500  271500  192699 -0.025135
# 2022-03-29  273000  275500  271000  273000  173269  0.005525
# 2022-03-30  274500  276500  271000  272500  147316 -0.001832
# 2022-03-31  272500  281500  272000  275500  187476  0.011009
# 2022-04-01  276500  278000  272000  278000  125727  0.009074
# 2022-04-04  275500  299500  275500  298500  507532  0.073741
# 2022-04-05  300500  301000  290500  293500  241079 -0.016750
# 2022-04-06  289000  296500  286000  287000  171374 -0.022147

# %%
from matplotlib import pyplot as plt
# plt.figure(figsize=(15,10))
# plt.subplot(221)
plt.plot(df['High'], 'bo-')
plt.xticks(rotation=45)

# plt.subplot(222)
# plt.plot(df_search['크래프톤'], 'b-')
# Out:
# (array([738242., 738243., 738244., 738245., 738246., 738247., 738248.,
#         738249., 738250., 738251.]),
#  <a list of 10 Text major ticklabel objects>)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = fdr.DataReader('377300','2022-03-28', '2022-04-06')
from matplotlib import pyplot as plt
plt.plot(df['High'], 'bo-')
plt.xticks(rotation=45)
# Out:
# (array([738242., 738243., 738244., 738245., 738246., 738247., 738248.,
#         738249., 738250., 738251.]),
#  <a list of 10 Text major ticklabel objects>)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = fdr.DataReader('005380','2022-03-28', '2022-04-06')
from matplotlib import pyplot as plt
plt.plot(df['High'], 'bo-')
plt.xticks(rotation=45)
# Out:
# (array([738242., 738243., 738244., 738245., 738246., 738247., 738248.,
#         738249., 738250., 738251.]),
#  <a list of 10 Text major ticklabel objects>)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = fdr.DataReader('003490','2022-03-28', '2022-04-06')
from matplotlib import pyplot as plt
plt.plot(df['High'], 'bo-')
plt.xticks(rotation=45)
# Out:
# (array([738242., 738243., 738244., 738245., 738246., 738247., 738248.,
#         738249., 738250., 738251.]),
#  <a list of 10 Text major ticklabel objects>)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
